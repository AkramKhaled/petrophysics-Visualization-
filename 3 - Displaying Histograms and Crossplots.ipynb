# %%
#loading libiraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
#loading file 
df3=pd.read_csv("L0509WellData.csv")
print(df3.head())
# Out:
#        DEPTH         GR          DT      RHOB      DRHO      NPHI
# 0  4609.8008  89.059479 -999.000000  2.483700  0.018494  0.129119
# 1  4609.9008  90.721848 -999.000000  2.489308  0.013656  0.108034
# 2  4610.0008  90.709061 -999.000000  2.501088  0.011289  0.085650
# 3  4610.1008  89.568954   66.223099  2.515450  0.008615  0.070332
# 4  4610.2008  88.169571   66.705551  2.530982  0.005628  0.065343

# %%
df3.replace(-999 , np.nan , inplace=True)
print(df3.head())
# Out:
#        DEPTH         GR         DT      RHOB      DRHO      NPHI
# 0  4609.8008  89.059479        NaN  2.483700  0.018494  0.129119
# 1  4609.9008  90.721848        NaN  2.489308  0.013656  0.108034
# 2  4610.0008  90.709061        NaN  2.501088  0.011289  0.085650
# 3  4610.1008  89.568954  66.223099  2.515450  0.008615  0.070332
# 4  4610.2008  88.169571  66.705551  2.530982  0.005628  0.065343

# %%
df3.hist( column="GR" , bins=30 , alpha=0.5 , color="grey")
# Out:
# array([[<AxesSubplot:title={'center':'GR'}>]], dtype=object)

# %% [markdown]
# Plotting multiple histograms on one plot

# %%
col_pl = list(df3)
col_pl.remove("DEPTH")
#Setup the number of rows and columns for our plot
rows=3
cols=2

fig=plt.figure(figsize=(15,10))
for index , feature in enumerate (col_pl):
    ax=fig.add_subplot(rows,cols,index+1)
    df3[feature].hist(bins=30 , color="pink" , ax=ax)
    ax.set_title(feature+"Disteribution")
    ax.grid(color="green")
    ax.set_axisbelow(True)
    
plt.tight_layout()  
plt.show()

# %% [markdown]
# Displaying data on a crossplot (Scatterplot)

# %%
df3.plot(kind="scatter" , x="NPHI" , y="RHOB" , c="GR" , colormap="YlOrRd_r" , ylim=(3,2))
plt.show()

# %%
# %matplotlib notebook
print()

# %%
from mp1_toolkits.mplot3d import Axis3d
fig=plt.figure(figsize(10,10))
ax=fig.add_subplot(111 , projection = "3d")
ax.scatter(df3["NPHI"], df3["RHOB"] , df3["GR"] , color="green" , alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5260\716803575.py in <module>
# ----> 1 from mp1_toolkits.mplot3d import Axis3d
#       2 fig=plt.figure(figsize(10,10))
#       3 ax=fig.add_subplot(111 , projection = "3d")
#       4 ax.scatter(df3["NPHI"], df3["RHOB"] , df3["GR"] , color="green" , alpha=0.5)
#       5 plt.show()
#
# ModuleNotFoundError: No module named 'mp1_toolkits'

# %% [markdown]
# multiple crossplots on view

# %%
print(df3.head())
# Out:
#        DEPTH         GR         DT      RHOB      DRHO      NPHI
# 0  4609.8008  89.059479        NaN  2.483700  0.018494  0.129119
# 1  4609.9008  90.721848        NaN  2.489308  0.013656  0.108034
# 2  4610.0008  90.709061        NaN  2.501088  0.011289  0.085650
# 3  4610.1008  89.568954  66.223099  2.515450  0.008615  0.070332
# 4  4610.2008  88.169571  66.705551  2.530982  0.005628  0.065343

# %%
fig,ax=plt.subplots(figsize=(10,10))

ax1=plt.subplot2grid((2,2) , (0,0) , rowspan=1 , colspan=1 )
ax2=plt.subplot2grid((2,2) , (0,1) , rowspan=1 , colspan = 1)
ax3=plt.subplot2grid((2,2) , (1,0) , rowspan=1 , colspan= 1)
ax4= plt.subplot2grid((2,2) , (1,1) , rowspan=1 , colspan=1)

ax1.scatter( x="NPHI" , y="RHOB" , data=df3 , alpha=0.2)
ax1.set_ylim(3,1.8)
ax1.set_ylabel("RHOB (g/cc)")
ax1.set_xlabel("NPHI (dec)")
ax1.grid()

ax2.scatter( x="GR" , y="RHOB" , data=df3 , color="red" , alpha=0.2)
ax2.set_xlabel("GR (API)")
ax2.set_ylabel("RHOB (g/cc)")
ax2.set_ylim(3,1.8) 
ax2.grid()

ax3.scatter(x="DT" , y="RHOB" , data=df3 , color="green" , alpha=0.2)
ax3.set_xlabel("DT (us/ft)")
ax3.set_ylabel("RHOB (g/cc)")
ax3.set_ylim(3,1.8)
ax3.grid()

ax4.scatter(x="GR" , y="DT" , data=df3 , color="Orange" , alpha=0.2)
ax4.set_ylabel("DT (us/ft)")
ax4.set_xlabel("GR (API)")
ax4.grid()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
